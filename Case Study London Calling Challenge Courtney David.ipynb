# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
import seaborn as sns


import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
#mtick and seaborn are used for the function format_ticks

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.shape
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# 0    E12000002          E12000003     E12000004     E12000005       E12000006
# 1  43958.48001        44803.42878   45544.52227   48527.52339      56701.5961
# 2  43925.42289        44528.80721   46051.57066   49341.29029     56593.59475
# 3   44434.8681        45200.46775   45383.82395   49442.17973     56171.18278
# 4   44267.7796        45614.34341   46124.23045   49455.93299     56567.89582
#
#         LONDON   SOUTH EAST   SOUTH WEST Unnamed: 47      England
# 0    E12000007    E12000008    E12000009         NaN    E92000001
# 1  74435.76052  64018.87894   54705.1579         NaN  53202.77128
# 2  72777.93709  63715.02399  54356.14843         NaN   53096.1549
# 3  73896.84204  64113.60858  53583.07667         NaN   53201.2843
# 4  74455.28754  64623.22395  54786.01938         NaN   53590.8548
#
# [5 rows x 49 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_T = properties.T.reset_index()
properties_T.columns = properties_T.iloc[0,:]
properties_T.head()
#the above code is used to transpose the dataframe
# Out:
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1          94900.51244          110128.0423          112329.4376  ...
# 2          53700.34831          52113.12157          52232.19868  ...
# 3          90107.23471          91441.24768          92361.31512  ...
# 4          64252.32335          63722.70055          64432.60005  ...
#
# 0  2021-09-01 00:00:00  2021-10-01 00:00:00  2021-11-01 00:00:00  \
# 0  2021-09-01 00:00:00  2021-10-01 00:00:00  2021-11-01 00:00:00
# 1          954883.5623           793389.303          799674.7093
# 2          315039.4514          326713.3328           328530.925
# 3          554751.7729          568918.4141          572810.1795
# 4          371845.6682          374878.1357          377659.1213
#
# 0  2021-12-01 00:00:00  2022-01-01 00:00:00  2022-02-01 00:00:00  \
# 0  2021-12-01 00:00:00  2022-01-01 00:00:00  2022-02-01 00:00:00
# 1          809376.0744          796047.1779          856301.3695
# 2          330850.6123          337556.8251          341428.3513
# 3          574877.2915          581452.9611          578243.1188
# 4          378364.5877          380927.4203           384241.381
#
# 0  2022-03-01 00:00:00  2022-04-01 00:00:00  2022-05-01 00:00:00  \
# 0  2022-03-01 00:00:00  2022-04-01 00:00:00  2022-05-01 00:00:00
# 1          820301.6021           860938.146          802499.9324
# 2          342723.2034          339305.0077          337715.1923
# 3          582655.2462          594130.6286          600963.0729
# 4          389416.9541          391216.7404          393388.7677
#
# 0  2022-06-01 00:00:00
# 0  2022-06-01 00:00:00
# 1           830376.165
# 2          342083.4519
# 3          599286.6158
# 4          395012.0758
#
# [5 rows x 332 columns]

# %%
properties_T = properties_T.drop([0])
properties_T.head()
#the code above is used to remove the first row of the properties_T dataframe
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# 2         53700.34831         52113.12157         52232.19868  ...
# 3         90107.23471         91441.24768         92361.31512  ...
# 4         64252.32335         63722.70055         64432.60005  ...
# 5         74310.48167         74127.03788          73547.0411  ...
#
# 0 2021-09-01 00:00:00 2021-10-01 00:00:00 2021-11-01 00:00:00  \
# 1         954883.5623          793389.303         799674.7093
# 2         315039.4514         326713.3328          328530.925
# 3         554751.7729         568918.4141         572810.1795
# 4         371845.6682         374878.1357         377659.1213
# 5         517734.2015         512019.2975          519123.411
#
# 0 2021-12-01 00:00:00 2022-01-01 00:00:00 2022-02-01 00:00:00  \
# 1         809376.0744         796047.1779         856301.3695
# 2         330850.6123         337556.8251         341428.3513
# 3         574877.2915         581452.9611         578243.1188
# 4         378364.5877         380927.4203          384241.381
# 5          522416.266         519263.5237         524082.1442
#
# 0 2022-03-01 00:00:00 2022-04-01 00:00:00 2022-05-01 00:00:00  \
# 1         820301.6021          860938.146         802499.9324
# 2         342723.2034         339305.0077         337715.1923
# 3         582655.2462         594130.6286         600963.0729
# 4         389416.9541         391216.7404         393388.7677
# 5         526105.1622         534127.0746         533332.6033
#
# 0 2022-06-01 00:00:00
# 1          830376.165
# 2         342083.4519
# 3         599286.6158
# 4         395012.0758
# 5         528087.4204
#
# [5 rows x 332 columns]

# %%
properties_T = properties_T.reset_index(drop=True)
properties_T.head()
#the above code is used to reset the index of the properties_T dataframe so that the index starts at 0 instead of 1
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001         91448.98487         82202.77314
# 1  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 2              Barnet  E09000003         93284.51832         93190.16963
# 3              Bexley  E09000004         64958.09036         64787.92069
# 4               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0         79120.70256         77101.20804         84409.14932
# 1         51268.96956         53133.50526         53042.24852
# 2         92247.52435         90762.87492         90258.00033
# 3         64367.49344         64277.66881         63997.13588
# 4         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 0         94900.51244         110128.0423         112329.4376  ...
# 1         53700.34831         52113.12157         52232.19868  ...
# 2         90107.23471         91441.24768         92361.31512  ...
# 3         64252.32335         63722.70055         64432.60005  ...
# 4         74310.48167         74127.03788          73547.0411  ...
#
# 0 2021-09-01 00:00:00 2021-10-01 00:00:00 2021-11-01 00:00:00  \
# 0         954883.5623          793389.303         799674.7093
# 1         315039.4514         326713.3328          328530.925
# 2         554751.7729         568918.4141         572810.1795
# 3         371845.6682         374878.1357         377659.1213
# 4         517734.2015         512019.2975          519123.411
#
# 0 2021-12-01 00:00:00 2022-01-01 00:00:00 2022-02-01 00:00:00  \
# 0         809376.0744         796047.1779         856301.3695
# 1         330850.6123         337556.8251         341428.3513
# 2         574877.2915         581452.9611         578243.1188
# 3         378364.5877         380927.4203          384241.381
# 4          522416.266         519263.5237         524082.1442
#
# 0 2022-03-01 00:00:00 2022-04-01 00:00:00 2022-05-01 00:00:00  \
# 0         820301.6021          860938.146         802499.9324
# 1         342723.2034         339305.0077         337715.1923
# 2         582655.2462         594130.6286         600963.0729
# 3         389416.9541         391216.7404         393388.7677
# 4         526105.1622         534127.0746         533332.6033
#
# 0 2022-06-01 00:00:00
# 0          830376.165
# 1         342083.4519
# 2         599286.6158
# 3         395012.0758
# 4         528087.4204
#
# [5 rows x 332 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_T = properties_T.rename(columns={"Unnamed: 0": "London_borough", pd.NaT : "id"})
# the above code is used to rename the 1st and 2nd column names.

# %%
properties_T.shape
properties_T.head()
# Out:
# 0      London_borough         id 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001         91448.98487         82202.77314
# 1  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 2              Barnet  E09000003         93284.51832         93190.16963
# 3              Bexley  E09000004         64958.09036         64787.92069
# 4               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0         79120.70256         77101.20804         84409.14932
# 1         51268.96956         53133.50526         53042.24852
# 2         92247.52435         90762.87492         90258.00033
# 3         64367.49344         64277.66881         63997.13588
# 4         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 0         94900.51244         110128.0423         112329.4376  ...
# 1         53700.34831         52113.12157         52232.19868  ...
# 2         90107.23471         91441.24768         92361.31512  ...
# 3         64252.32335         63722.70055         64432.60005  ...
# 4         74310.48167         74127.03788          73547.0411  ...
#
# 0 2021-09-01 00:00:00 2021-10-01 00:00:00 2021-11-01 00:00:00  \
# 0         954883.5623          793389.303         799674.7093
# 1         315039.4514         326713.3328          328530.925
# 2         554751.7729         568918.4141         572810.1795
# 3         371845.6682         374878.1357         377659.1213
# 4         517734.2015         512019.2975          519123.411
#
# 0 2021-12-01 00:00:00 2022-01-01 00:00:00 2022-02-01 00:00:00  \
# 0         809376.0744         796047.1779         856301.3695
# 1         330850.6123         337556.8251         341428.3513
# 2         574877.2915         581452.9611         578243.1188
# 3         378364.5877         380927.4203          384241.381
# 4          522416.266         519263.5237         524082.1442
#
# 0 2022-03-01 00:00:00 2022-04-01 00:00:00 2022-05-01 00:00:00  \
# 0         820301.6021          860938.146         802499.9324
# 1         342723.2034         339305.0077         337715.1923
# 2         582655.2462         594130.6286         600963.0729
# 3         389416.9541         391216.7404         393388.7677
# 4         526105.1622         534127.0746         533332.6033
#
# 0 2022-06-01 00:00:00
# 0          830376.165
# 1         342083.4519
# 2         599286.6158
# 3         395012.0758
# 4         528087.4204
#
# [5 rows x 332 columns]

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_T = pd.melt(properties_T,id_vars=['London_borough','id'])

# %%
properties_T.head()
# Out:
#        London_borough         id          0        value
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %%
properties_T = properties_T.rename(columns={0: "Month", "value" : "Avg_home_price"})
# the above code renames the columns value and zero(0) to the strings "Avg_home_price" and "Month"

# %%
properties_T.head()
# Out:
#        London_borough         id      Month Avg_home_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01     50460.2266
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_T.isna().any()
# properties_T = properties_T.dropna()
properties_T["Avg_home_price"] = pd.to_numeric(properties_T["Avg_home_price"])
# the above code converts the Avg_home_price column to numeric

# %%
properties_T.dtypes
# Out:
# London_borough            object
# id                        object
# Month             datetime64[ns]
# Avg_home_price           float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
properties_T.dtypes
# properties_T.isna().any()
properties_T.count()
# Out:
# London_borough    15840
# id                14850
# Month             15840
# Avg_home_price    14850
# dtype: int64

# %%
properties_T["London_borough"].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
properties_T[properties_T["London_borough"] == 'Unnamed: 37']
# Out:
#       London_borough   id      Month  Avg_home_price
# 36       Unnamed: 37  NaN 1995-01-01             NaN
# 84       Unnamed: 37  NaN 1995-02-01             NaN
# 132      Unnamed: 37  NaN 1995-03-01             NaN
# 180      Unnamed: 37  NaN 1995-04-01             NaN
# 228      Unnamed: 37  NaN 1995-05-01             NaN
# ...              ...  ...        ...             ...
# 15636    Unnamed: 37  NaN 2022-02-01             NaN
# 15684    Unnamed: 37  NaN 2022-03-01             NaN
# 15732    Unnamed: 37  NaN 2022-04-01             NaN
# 15780    Unnamed: 37  NaN 2022-05-01             NaN
# 15828    Unnamed: 37  NaN 2022-06-01             NaN
#
# [330 rows x 4 columns]

# %%
properties_T[properties_T["London_borough"] == 'Unnamed: 34']
# Out:
#       London_borough   id      Month  Avg_home_price
# 33       Unnamed: 34  NaN 1995-01-01             NaN
# 81       Unnamed: 34  NaN 1995-02-01             NaN
# 129      Unnamed: 34  NaN 1995-03-01             NaN
# 177      Unnamed: 34  NaN 1995-04-01             NaN
# 225      Unnamed: 34  NaN 1995-05-01             NaN
# ...              ...  ...        ...             ...
# 15633    Unnamed: 34  NaN 2022-02-01             NaN
# 15681    Unnamed: 34  NaN 2022-03-01             NaN
# 15729    Unnamed: 34  NaN 2022-04-01             NaN
# 15777    Unnamed: 34  NaN 2022-05-01             NaN
# 15825    Unnamed: 34  NaN 2022-06-01             NaN
#
# [330 rows x 4 columns]

# %%
properties_T[properties_T["London_borough"] == 'Unnamed: 47']
# Out:
#       London_borough   id      Month  Avg_home_price
# 46       Unnamed: 47  NaN 1995-01-01             NaN
# 94       Unnamed: 47  NaN 1995-02-01             NaN
# 142      Unnamed: 47  NaN 1995-03-01             NaN
# 190      Unnamed: 47  NaN 1995-04-01             NaN
# 238      Unnamed: 47  NaN 1995-05-01             NaN
# ...              ...  ...        ...             ...
# 15646    Unnamed: 47  NaN 2022-02-01             NaN
# 15694    Unnamed: 47  NaN 2022-03-01             NaN
# 15742    Unnamed: 47  NaN 2022-04-01             NaN
# 15790    Unnamed: 47  NaN 2022-05-01             NaN
# 15838    Unnamed: 47  NaN 2022-06-01             NaN
#
# [330 rows x 4 columns]

# %%
nonena = properties_T.dropna()
# the above code removes the rows in the properties_T dataframe that contain na values

# %%
nonena.count()
# Out:
# London_borough    14850
# id                14850
# Month             14850
# Avg_home_price    14850
# dtype: int64

# %%
non_boroughs = [
       'Inner London', 'Outer London',  'NORTH EAST',
       'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
       'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
       'SOUTH WEST',  'England' , 'City of London'
]
#the above code is a list of nonena dataframe that aren't actually london boroughs

# %%
nonena = nonena[nonena["London_borough"].isin(non_boroughs) == False]
#the above code is used to subset the nonena dataframe for rows that are not in the non_boroughs list

# %%
nonena["London_borough"].nunique()
#the below output shows the 32 boroughs
# Out:
# 32

# %%
nonena.count()
# Out:
# London_borough    10560
# id                10560
# Month             10560
# Avg_home_price    10560
# dtype: int64

# %%
nonena.head()
# Out:
#        London_borough         id      Month  Avg_home_price
# 1  Barking & Dagenham  E09000002 1995-01-01     50460.22660
# 2              Barnet  E09000003 1995-01-01     93284.51832
# 3              Bexley  E09000004 1995-01-01     64958.09036
# 4               Brent  E09000005 1995-01-01     71306.56698
# 5             Bromley  E09000006 1995-01-01     81671.47692

# %%
nonena.reset_index(drop=True)
# Out:
#            London_borough         id      Month  Avg_home_price
# 0      Barking & Dagenham  E09000002 1995-01-01     50460.22660
# 1                  Barnet  E09000003 1995-01-01     93284.51832
# 2                  Bexley  E09000004 1995-01-01     64958.09036
# 3                   Brent  E09000005 1995-01-01     71306.56698
# 4                 Bromley  E09000006 1995-01-01     81671.47692
# ...                   ...        ...        ...             ...
# 10555              Sutton  E09000029 2022-06-01    437192.36810
# 10556       Tower Hamlets  E09000030 2022-06-01    484026.09040
# 10557      Waltham Forest  E09000031 2022-06-01    501172.30330
# 10558          Wandsworth  E09000032 2022-06-01    638840.62270
# 10559         Westminster  E09000033 2022-06-01    944440.74650
#
# [10560 rows x 4 columns]

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
y_tick = mtick.StrMethodFormatter('€{x:,.0f}')

# function used for formating the y-axis scientific notation float numbers
def format_ticks():
    """Formats Date vs. Price Ticks"""
    
    plt.xlabel('Date')
    plt.ylabel('Home price(€)')
    
    # format y_tick
    ax=plt.gca()
    ax.yaxis.set_major_formatter(y_tick)
#the above code is used to define a custom function for formatting the y-ticks of the plot

# %%
nonena.groupby(by='London_borough')['Avg_home_price'].plot(kind='line',figsize=(15,10))
plt.title("Average home price(€) of different London boroughs over time")
format_ticks()
plt.legend()
plt.show()
#the above code is used plot the avg home price for each london borough by (month/year) date

# %%
nonena.sort_values("Avg_home_price", ascending= False).plot(x = 'Month', y = 'Avg_home_price', kind='line')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
nonena.pivot(index="Month",columns="London_borough",values="Avg_home_price").plot(kind='line',figsize=(15,10))
plt.xlabel("Month")
plt.ylabel("Home price(€)")
plt.title("Average home price(€) of different London boroughs over time")
format_ticks()
plt.show()

# %%
nonena.groupby(by=["London_borough"])["Avg_home_price"].describe()
# Out:
#                       count           mean            std           min  \
# London_borough
# Barking & Dagenham    330.0  173538.854245   85392.069539   50460.22660
# Barnet                330.0  326509.505763  152046.074410   90107.23471
# Bexley                330.0  204743.559899   95303.850699   63722.70055
# Brent                 330.0  291260.353836  144966.573213   71306.56698
# Bromley               330.0  272089.327941  122654.212706   81124.41227
# Camden                330.0  500438.629946  253949.877776  115418.83960
# Croydon               330.0  225358.715748  103341.523769   68006.00735
# Ealing                330.0  294371.222384  138488.779824   79272.34618
# Enfield               330.0  240623.111854  111907.106092   70630.77955
# Greenwich             330.0  230021.871385  113430.000191   60993.26863
# Hackney               330.0  312752.849355  177334.046400   61296.52637
# Hammersmith & Fulham  330.0  470490.363572  222107.014178  120635.94670
# Haringey              330.0  317317.988567  165947.579039   76287.56947
# Harrow                330.0  287622.305129  128606.747000   82054.42111
# Havering              330.0  221161.278108  102358.409135   66181.79433
# Hillingdon            330.0  250397.807823  114678.267492   71760.09266
# Hounslow              330.0  252140.486297  111724.672004   71051.55852
# Islington             330.0  393178.868479  200054.074927   89406.19881
# Kensington & Chelsea  330.0  794942.411539  417586.294912  182345.24630
# Kingston upon Thames  330.0  301604.141178  140275.626650   80875.84843
# Lambeth               330.0  301711.517074  156866.203784   65381.51908
# Lewisham              330.0  235695.526892  125047.452395   57700.33538
# Merton                330.0  304228.532452  152235.591352   79569.22895
# Newham                330.0  212269.561193  107611.702230   53153.88306
# Redbridge             330.0  253581.112101  118653.232413   72141.62610
# Richmond upon Thames  330.0  411318.987366  194030.843142  106875.00000
# Southwark             330.0  296272.752866  155446.910370   60885.98483
# Sutton                330.0  233157.645593  105187.441388   69290.69004
# Tower Hamlets         330.0  275812.547133  132124.509905   59865.18995
# Waltham Forest        330.0  242198.530754  134365.613192   60252.12246
# Wandsworth            330.0  366490.225799  181836.768787   86518.05945
# Westminster           330.0  580976.570459  314321.233436  131468.30960
#
#                                 25%           50%           75%           max
# London_borough
# Barking & Dagenham     96116.141345  165238.33085  2.402266e+05  3.427232e+05
# Barnet                199155.631175  318971.68280  4.774275e+05  6.009631e+05
# Bexley                122670.843000  199558.00830  2.791105e+05  3.950121e+05
# Brent                 164695.913600  281162.16180  4.359731e+05  5.341271e+05
# Bromley               171297.992925  266572.07745  3.880150e+05  5.085449e+05
# Camden                289356.129375  473786.82810  7.866890e+05  8.902884e+05
# Croydon               140499.918675  216699.07390  3.113852e+05  4.166411e+05
# Ealing                177977.984250  286783.71075  4.442536e+05  5.376948e+05
# Enfield               144501.741275  235237.03310  3.419267e+05  4.535521e+05
# Greenwich             134397.586175  222918.14850  3.403403e+05  4.403753e+05
# Hackney               161244.568125  294907.93095  5.119766e+05  6.417310e+05
# Hammersmith & Fulham  278966.444175  472462.76495  7.167489e+05  8.538705e+05
# Haringey              173391.848650  295686.10755  4.849135e+05  5.951282e+05
# Harrow                179933.383150  285186.19765  4.152544e+05  5.235089e+05
# Havering              132272.361200  217870.70300  2.937302e+05  4.289886e+05
# Hillingdon            153841.242475  245818.71705  3.550828e+05  4.653523e+05
# Hounslow              161287.623875  252997.71680  3.577194e+05  4.412694e+05
# Islington             228248.259450  376966.62790  6.269272e+05  7.349465e+05
# Kensington & Chelsea  423766.294125  763001.40975  1.247982e+06  1.463378e+06
# Kingston upon Thames  187563.421075  295516.79955  4.453902e+05  5.412752e+05
# Lambeth               169983.523575  289853.49935  4.846136e+05  5.450969e+05
# Lewisham              130520.470550  223207.60630  3.593456e+05  4.550052e+05
# Merton                176181.044050  290152.48110  4.681783e+05  5.819970e+05
# Newham                119380.950275  206718.83840  3.004910e+05  4.145859e+05
# Redbridge             153440.643300  250321.75010  3.494559e+05  4.738652e+05
# Richmond upon Thames  251561.801275  406628.97075  6.285947e+05  7.701742e+05
# Southwark             172258.693475  287666.52585  4.807232e+05  5.448410e+05
# Sutton                147666.502325  230429.70210  3.264230e+05  4.371924e+05
# Tower Hamlets         170120.495575  277799.98815  4.255992e+05  4.840261e+05
# Waltham Forest        131709.482050  219496.76100  3.636588e+05  5.011723e+05
# Wandsworth            211797.156100  359284.06685  5.730701e+05  6.454543e+05
# Westminster           310051.765000  538869.87945  9.284919e+05  1.117408e+06

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
nonena['Date_Year']= pd.DatetimeIndex(nonena['Month']).year
# df['Year'] = df['Month'].apply(lambda t: t.year)
# the above code adds a new column to the nonena dataframe called Date_Year

# %%
nonena.head()
# Out:
#        London_borough         id      Month  Avg_home_price  Date_Year
# 1  Barking & Dagenham  E09000002 1995-01-01     50460.22660       1995
# 2              Barnet  E09000003 1995-01-01     93284.51832       1995
# 3              Bexley  E09000004 1995-01-01     64958.09036       1995
# 4               Brent  E09000005 1995-01-01     71306.56698       1995
# 5             Bromley  E09000006 1995-01-01     81671.47692       1995

# %%
df = nonena

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#        London_borough         id      Month  Avg_home_price  Date_Year
# 0  Barking & Dagenham  E09000002 1995-01-01     50460.22660       1995
# 1              Barnet  E09000003 1995-01-01     93284.51832       1995
# 2              Bexley  E09000004 1995-01-01     64958.09036       1995
# 3               Brent  E09000005 1995-01-01     71306.56698       1995
# 4             Bromley  E09000006 1995-01-01     81671.47692       1995

# %%
dfg = df.groupby(by=["London_borough","Date_Year"]).mean()
dfg.sample(10)
#the above code creates a new dataframe dfg that contains all the avg_home_prices for each borough by year.
# Out:
#                                 Avg_home_price
# London_borough       Date_Year
# Kingston upon Thames 2005        251156.254508
# Lewisham             2005        190867.854550
# Havering             2017        360479.242133
# Islington            2022        713289.677167
# Hounslow             2009        236242.593458
# Haringey             2012        339685.912767
# Bromley              2007        277229.950892
# Enfield              2015        335503.499742
# Merton               2008        300674.501150
# Redbridge            2012        265912.046092

# %%
dfg = dfg.reset_index()
dfg.head()
# Out:
#        London_borough  Date_Year  Avg_home_price
# 0  Barking & Dagenham       1995    51817.969390
# 1  Barking & Dagenham       1996    51718.192690
# 2  Barking & Dagenham       1997    55974.262309
# 3  Barking & Dagenham       1998    60285.821083
# 4  Barking & Dagenham       1999    65320.934441

# %%
dfg.pivot(index="Date_Year",columns="London_borough",values="Avg_home_price").plot(kind='line',figsize=(15,10))
plt.title('Plot of all boroughs avg home price(€) by Year')
format_ticks()
#the below plot shows a plot the final dataframe dfg with the relationship between the avg-home-price of each london borough by the year

# %%
for x in dfg['London_borough'].unique():
    
    
    dfg_sub = dfg[dfg.London_borough == x]
    
    if x == 'Kensington & Chelsea':
        plt.plot(dfg_sub['Date_Year'],dfg_sub['Avg_home_price'],linewidth = 1, color = 'blue', label ='#1 '+x)
        
    elif x == 'Barking & Dagenham':
        plt.plot(dfg_sub['Date_Year'],dfg_sub['Avg_home_price'],linewidth = 1, color = 'red', label ='#2 '+x)
        
    elif x == 'Westminister':
        plt.plot(dfg_sub['Date_Year'],dfg_sub['Avg_home_price'],linewidth = 0.7, color = 'grey', label ='#3 '+x)
    
    else:
        plt.plot(dfg_sub['Date_Year'],dfg_sub['Avg_home_price'],linewidth = 0.2, alpha = 0.8)
    
plt.title('Plot of all boroughs avg price() by Year')


ax = plt.gca()
handles,labels = ax.get_legend_handles_labels()
ax.legend()

format_ticks() 
plt.show()   
#the above code is used to generate a plot that will reduce the number of datapoints by only plotting data for avg_home_price for each london borough by year

# %%
dfg.groupby(["London_borough"])['Avg_home_price'].mean().sort_values(ascending=False)
#the above code shows the london boroughs' average home price over time, with the most expensive price at the beginning of the Series and the least expensive at the bottom
# Out:
# London_borough
# Kensington & Chelsea    805863.863532
# Westminster             588418.510444
# Camden                  506953.625470
# Hammersmith & Fulham    475575.873032
# Richmond upon Thames    417506.315651
# Islington               398895.132920
# Wandsworth              371383.538824
# Barnet                  331204.965908
# Haringey                322141.497182
# Hackney                 318242.037597
# Merton                  308834.349152
# Lambeth                 306001.975184
# Kingston upon Thames    305693.251423
# Southwark               300465.782099
# Ealing                  298486.810262
# Brent                   295478.912780
# Harrow                  291609.224933
# Tower Hamlets           279302.030891
# Bromley                 275949.864400
# Redbridge               257463.447124
# Hounslow                255326.560886
# Hillingdon              253964.113978
# Waltham Forest          246520.512690
# Enfield                 244209.195737
# Lewisham                239438.864780
# Sutton                  236600.487109
# Greenwich               233472.442347
# Croydon                 228707.293726
# Havering                224643.871090
# Newham                  215678.605667
# Bexley                  208034.458649
# Barking & Dagenham      176513.791466
# Name: Avg_home_price, dtype: float64

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
dfg[dfg['London_borough'] == 'Camden']
#the above code is used to defiine a function for calculating the ratio of average home prices in (2018/1998)
# Out:
#     London_borough  Date_Year  Avg_home_price
# 140         Camden       1995   120367.431783
# 141         Camden       1996   133810.487933
# 142         Camden       1997   150142.901208
# 143         Camden       1998   170688.973933
# 144         Camden       1999   191090.697392
# 145         Camden       2000   247114.633575
# 146         Camden       2001   278594.043717
# 147         Camden       2002   314179.507833
# 148         Camden       2003   323053.850375
# 149         Camden       2004   351847.799300
# 150         Camden       2005   368345.084125
# 151         Camden       2006   394819.367875
# 152         Camden       2007   466485.642400
# 153         Camden       2008   501223.236400
# 154         Camden       2009   454628.074967
# 155         Camden       2010   513221.129450
# 156         Camden       2011   554392.962617
# 157         Camden       2012   586165.935192
# 158         Camden       2013   667447.558742
# 159         Camden       2014   756486.472617
# 160         Camden       2015   787440.932900
# 161         Camden       2016   807118.961958
# 162         Camden       2017   839347.476208
# 163         Camden       2018   842410.409361
# 164         Camden       2019   843066.936333
# 165         Camden       2020   829863.237433
# 166         Camden       2021   836069.388208
# 167         Camden       2022   865278.379333

# %%
def create_price_ratio(dfg_filter_borough):
    
    # definition of price_1998 and price_2018
    price_1998 = float(dfg_filter_borough[dfg_filter_borough['Date_Year'] == 1998]['Avg_home_price'])
    price_2018 = float(dfg_filter_borough[dfg_filter_borough['Date_Year'] == 2018]['Avg_home_price'])
    
    ratio_prices = price_2018 / price_1998
    
    return (ratio_prices)
    


#printing with .format()
"The ratio of avg_home_price (2018/1998) for the greenwich borrough is: {}".format(create_price_ratio(dfg[dfg["London_borough"] == 'Greenwich'])) 

#printing with f"str{}
f"The ratio of avg_home_price (2018/1998) for the greenwich borrough is: {create_price_ratio(dfg[dfg['London_borough'] == 'Greenwich'])}"
# Out:
# 'The ratio of avg_home_price (2018/1998) for the greenwich borrough is: 4.7630363473291935'

# %%
ratios = {}
for b in dfg['London_borough'].unique():
    
    df_new = dfg[dfg['London_borough'] == b]
    ratios[b] = create_price_ratio(df_new)
    
print(ratios)
#the above code is used to iterate and traverse through the unique london boroughs column and calculate the ratio of average home prices in (1998/2018) for each borough. The unique borrow names are the keys of the ratios dict and the corresponding ratio values are the values of the dict.
# Out:
# {'Barking & Dagenham': 4.89661861291754, 'Barnet': 4.358195917538044, 'Bexley': 4.248977046127877, 'Brent': 4.8945544971392865, 'Bromley': 4.094784685333876, 'Camden': 4.935353408884261, 'Croydon': 4.201100280024766, 'Ealing': 4.311450902121834, 'Enfield': 4.263471583495811, 'Greenwich': 4.7630363473291935, 'Hackney': 6.198285561008663, 'Hammersmith & Fulham': 4.13779810193623, 'Haringey': 5.134624964136042, 'Harrow': 4.0591964329643195, 'Havering': 4.325230371335307, 'Hillingdon': 4.2002730803844575, 'Hounslow': 3.976409106143329, 'Islington': 4.844048012802297, 'Kensington & Chelsea': 5.082465066092464, 'Kingston upon Thames': 4.270549521484271, 'Lambeth': 4.957751163514062, 'Lewisham': 5.449221041059686, 'Merton': 4.741273313294603, 'Newham': 5.305390437201879, 'Redbridge': 4.471182006097364, 'Richmond upon Thames': 4.005161895721457, 'Southwark': 5.516485302379378, 'Sutton': 4.118522608573157, 'Tower Hamlets': 4.62670104006116, 'Waltham Forest': 5.83475580932281, 'Wandsworth': 4.75770934773927, 'Westminster': 5.353565392605412}

# %%
ratios_dfg = pd.DataFrame([ratios])
ratios_dfg
#the above code is used to convert the list of the single ratios dict into a useable dataframe and to transpose the dataframe
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    Croydon    Ealing   Enfield  Greenwich  ...    Merton   Newham  Redbridge  \
# 0   4.2011  4.311451  4.263472   4.763036  ...  4.741273  5.30539   4.471182
#
#    Richmond upon Thames  Southwark    Sutton  Tower Hamlets  Waltham Forest  \
# 0              4.005162   5.516485  4.118523       4.626701        5.834756
#
#    Wandsworth  Westminster
# 0    4.757709     5.353565
#
# [1 rows x 32 columns]

# %%
ratios_dfg = ratios_dfg.T.reset_index()

# %%
ratios_dfg.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
ratios_dfg = ratios_dfg.rename(columns={"index": "London_borough", 0 : "Avg_home_price_ratio of yrs (2018/1998)"})
sorted_ratios_dfg = ratios_dfg.sort_values("Avg_home_price_ratio of yrs (2018/1998)",ascending = False)
#the above code is used to create a new sorted version of the ratios_df in descending ratio values

# %%
sorted_ratios_dfg
# Out:
#           London_borough  Avg_home_price_ratio of yrs (2018/1998)
# 10               Hackney                                 6.198286
# 29        Waltham Forest                                 5.834756
# 26             Southwark                                 5.516485
# 21              Lewisham                                 5.449221
# 31           Westminster                                 5.353565
# 23                Newham                                 5.305390
# 12              Haringey                                 5.134625
# 18  Kensington & Chelsea                                 5.082465
# 20               Lambeth                                 4.957751
# 5                 Camden                                 4.935353
# 0     Barking & Dagenham                                 4.896619
# 3                  Brent                                 4.894554
# 17             Islington                                 4.844048
# 9              Greenwich                                 4.763036
# 30            Wandsworth                                 4.757709
# 22                Merton                                 4.741273
# 28         Tower Hamlets                                 4.626701
# 24             Redbridge                                 4.471182
# 1                 Barnet                                 4.358196
# 14              Havering                                 4.325230
# 7                 Ealing                                 4.311451
# 19  Kingston upon Thames                                 4.270550
# 8                Enfield                                 4.263472
# 2                 Bexley                                 4.248977
# 6                Croydon                                 4.201100
# 15            Hillingdon                                 4.200273
# 11  Hammersmith & Fulham                                 4.137798
# 27                Sutton                                 4.118523
# 4                Bromley                                 4.094785
# 13                Harrow                                 4.059196
# 25  Richmond upon Thames                                 4.005162
# 16              Hounslow                                 3.976409

# %%
top_15 = sorted_ratios_dfg.head(15)
top_15
# Out:
#           London_borough  Avg_home_price_ratio of yrs (2018/1998)
# 10               Hackney                                 6.198286
# 29        Waltham Forest                                 5.834756
# 26             Southwark                                 5.516485
# 21              Lewisham                                 5.449221
# 31           Westminster                                 5.353565
# 23                Newham                                 5.305390
# 12              Haringey                                 5.134625
# 18  Kensington & Chelsea                                 5.082465
# 20               Lambeth                                 4.957751
# 5                 Camden                                 4.935353
# 0     Barking & Dagenham                                 4.896619
# 3                  Brent                                 4.894554
# 17             Islington                                 4.844048
# 9              Greenwich                                 4.763036
# 30            Wandsworth                                 4.757709

# %%
ax = top_15[['London_borough','Avg_home_price_ratio of yrs (2018/1998)']].plot(kind='bar',figsize=(15,8))

ax.set_xticklabels(top_15.London_borough);
plt.title('Plot of all boroughs ratio of avg home price for yrs (2018/1998)');
plt.xlabel("London_borough");
plt.ylabel("ratio of avg home price for yrs (2018/1998)");
#the above code is used to view the top 15 london boroughs in a bar plot

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# Summary:
# The problem statement: Which london borough(s) saw the greatest increase in average housing prices in the last two decades (20years)?
# Based on the anaylsis of the data above: The Avg_home_price_ratio of yrs (1998/2018) column shows that the Hackney borough saw the highest value in the average home price increase in the last two decades; a price increase of about €460,000 from €88,000 to €545,000 which is a price increase of around 520% , followed by Waltham forrest etc.
# The Hounslow borough was the lowest average home price increase in the last two decades; a price increase of about €297,000 from €100,000 to €397,000, with a price increase of around 298%. Kensington and Chelsea had an  Avg_home_price_ratio of 5.0.
